# %% [markdown]
# # Source to the original dataset
# https://www.espncricinfo.com/records/highest-career-batting-average-282910

# %%
#import pandas as pd

# %%
import pandas as pd

# %%
#import CSV

# %%
df = pd.read_csv('Dataset_Cricket.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs   HS     Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1   YBK Jaiswal (IND)  2023-2024   11    20   1  1217  214*  64.05   1698
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 61  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
#Rename multiple columns in a list

# %%
df = df.rename(columns = {'Mat':'Matches', 'NO': 'Not_Outs', 'HS ':'Highest_Inns_Score', 'BF': 'Balls_Faced', 'SR':'Batting_Strike_Rate'})

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1   YBK Jaiswal (IND)  2023-2024       11    20         1  1217
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 60  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 61  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 62  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 63    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 64   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
#Check Null values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Batting_Strike_Rate'].isna() == 1]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8    ED Weekes (WI)  1948-1958       48    81         5  4455
# 15  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 8                 207  58.61           -                  NaN   15  19  6
# 15                220  56.68           -                  NaN   15  14  1
#
#       4s  6s
# 8   258+   2
# 15  107+  11

# %%
#Replace Null values with 0

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
df[df['Batting_Strike_Rate'].isna() == 1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s]
# Index: []

# %%
df[df['Player'] == 'CL Walcott (WI)']
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 15  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 15                220  56.68           -                  0.0   15  14  1
#
#       4s  6s
# 15  107+  11

# %%
#Drop Duplicates

# %%
df[df.duplicated() == 1]
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 14     JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 61  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 14                211  56.94       5363+                46.22   15  28   4
# 61                277  48.25       15525                59.67   27  38  11
#
#       4s  6s
# 14  276+   8
# 61  1165  24

# %%
#Checking duplicates by player names

# %%
df[df['Player'].duplicated() == 1]
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 14     JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 61  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 14                211  56.94       5363+                46.22   15  28   4
# 61                277  48.25       15525                59.67   27  38  11
#
#       4s  6s
# 14  276+   8
# 61  1165  24

# %%
df[df['Player'].isin(['JB Hobbs (ENG)', 'GC Smith (ICC/SA)'])]
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 13     JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 14     JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 60  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 61  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 13                211  56.94       5363+                46.22   15  28   4
# 14                211  56.94       5363+                46.22   15  28   4
# 60                277  48.25       15525                59.67   27  38  11
# 61                277  48.25       15525                59.67   27  38  11
#
#       4s  6s
# 13  276+   8
# 14  276+   8
# 60  1165  24
# 61  1165  24

# %%
df.drop_duplicates()
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1   YBK Jaiswal (IND)  2023-2024       11    20         1  1217
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 59   KD Walters (AUS)  1965-1981       74   125        14  5357
# 60  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 62  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 63    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 64   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['JB Hobbs (ENG)', 'GC Smith (ICC/SA)'])]
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 13     JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 60  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 13                211  56.94       5363+                46.22   15  28   4
# 60                277  48.25       15525                59.67   27  38  11
#
#       4s  6s
# 13  276+   8
# 60  1165  24

# %%
#Split up Span into Start and End Date + Career Length

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2023, 2024]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 59    [1965, 1981]
# 60    [2002, 2014]
# 62    [1924, 1934]
# 63    [1930, 1938]
# 64    [1928, 1934]
# Name: Span, Length: 63, dtype: object

# %%
df['Span'].str.split(pat = '-').str[0]
# Out:
# 0     1928
# 1     2023
# 2     2015
# 3     1963
# 4     1930
#       ...
# 59    1965
# 60    2002
# 62    1924
# 63    1930
# 64    1928
# Name: Span, Length: 63, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]
# Out:
# C:\Users\thapa\AppData\Local\Temp\ipykernel_30396\3648638022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]
# Out:
# C:\Users\thapa\AppData\Local\Temp\ipykernel_30396\3090471237.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1   YBK Jaiswal (IND)  2023-2024       11    20         1  1217
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 59   KD Walters (AUS)  1965-1981       74   125        14  5357
# 60  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 62  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 63    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 64   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
#Drop Span Columns

# %%
df.drop(['Span'], axis = 1)
# Out:
#                Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score  \
# 0    DG Bradman (AUS)       52    80        10  6996                334
# 1   YBK Jaiswal (IND)       11    20         1  1217               214*
# 2      AC Voges (AUS)       20    31         7  1485               269*
# 3     RG Pollock (SA)       23    41         4  2256                274
# 4     GA Headley (WI)       22    40         4  2190               270*
# ..                ...      ...   ...       ...   ...                ...
# 59   KD Walters (AUS)       74   125        14  5357                250
# 60  GC Smith (ICC/SA)      117   205        13  9265                277
# 62  WH Ponsford (AUS)       29    48         4  2122                266
# 63    SJ McCabe (AUS)       39    62         5  2748                232
# 64   DR Jardine (ENG)       22    33         6  1296                127
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
df = df.drop(['Span'], axis = 1)

# %%
df.head()
# Out:
#               Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1  YBK Jaiswal (IND)       11    20         1  1217               214*  64.05
# 2     AC Voges (AUS)       20    31         7  1485               269*  61.87
# 3    RG Pollock (SA)       23    41         4  2256                274  60.97
# 4    GA Headley (WI)       22    40         4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        1698                71.67    3   7  1   139  32        2023
# 2        2667                55.68    5   4  2   186   5        2015
# 3       1707+                54.48    7  11  1  246+  11        1963
# 4        416+                56.00   10   5  2  104+   1        1930
#
#   Final_Year
# 0       1948
# 1       2024
# 2       2016
# 3       1970
# ...

# %%
#QUESTION -> Split up the Country from the player

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1     [YBK Jaiswal , IND)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 59     [KD Walters , AUS)]
# 60    [GC Smith , ICC/SA)]
# 62    [WH Ponsford , AUS)]
# 63      [SJ McCabe , AUS)]
# 64     [DR Jardine , ENG)]
# Name: Player, Length: 63, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country']
# Out:
# 0        AUS)
# 1        IND)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 59       AUS)
# 60    ICC/SA)
# 62       AUS)
# 63       AUS)
# 64       ENG)
# Name: Country, Length: 63, dtype: object

# %%
df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1        IND
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 59       AUS
# 60    ICC/SA
# 62       AUS
# 63       AUS
# 64       ENG
# Name: Country, Length: 63, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman        52    80        10  6996                334  99.94
# 1  YBK Jaiswal        11    20         1  1217               214*  64.05
# 2     AC Voges        20    31         7  1485               269*  61.87
# 3   RG Pollock        23    41         4  2256                274  60.97
# 4   GA Headley        22    40         4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        1698                71.67    3   7  1   139  32        2023
# 2        2667                55.68    5   4  2   186   5        2015
# 3       1707+                54.48    7  11  1  246+  11        1963
# 4        416+                56.00   10   5  2  104+   1        1930
#
#   Final_Year Country
# 0       1948     AUS
# 1       2024     IND
# 2       2016     AUS
# ...

# %%
#Change DataTypes

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     214
# 2     269
# 3     274
# 4     270
#      ...
# 59    250
# 60    277
# 62    266
# 63    232
# 64    127
# Name: Highest_Inns_Score, Length: 63, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                334  99.94
# 1   YBK Jaiswal        11    20         1  1217                214  64.05
# 2      AC Voges        20    31         7  1485                269  61.87
# 3    RG Pollock        23    41         4  2256                274  60.97
# 4    GA Headley        22    40         4  2190                270  60.83
# ..           ...      ...   ...       ...   ...                ...    ...
# 59   KD Walters        74   125        14  5357                250  48.26
# 60     GC Smith       117   205        13  9265                277  48.25
# 62  WH Ponsford        29    48         4  2122                266  48.22
# 63    SJ McCabe        39    62         5  2748                232  48.21
# 64   DR Jardine        22    33         6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
df['Highest_Inns_Score'].astype('int')
# Out:
# 0     334
# 1     214
# 2     269
# 3     274
# 4     270
#      ...
# 59    250
# 60    277
# 62    266
# 63    232
# 64    127
# Name: Highest_Inns_Score, Length: 63, dtype: int32

# %%
df = df.astype({'Rookie_Year':'int', 'Final_Year':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df['4s'] = df['4s'].str.split(pat = '+').str[0]

# %%
df['6s'] = df['6s'].str.split(pat = '+').str[0]

# %%
df = df.astype({'4s':'int', '6s':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int32
# 6s                       int32
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                334  99.94
# 1   YBK Jaiswal        11    20         1  1217                214  64.05
# 2      AC Voges        20    31         7  1485                269  61.87
# 3    RG Pollock        23    41         4  2256                274  60.97
# 4    GA Headley        22    40         4  2190                270  60.83
# ..           ...      ...   ...       ...   ...                ...    ...
# 59   KD Walters        74   125        14  5357                250  48.26
# 60     GC Smith       117   205        13  9265                277  48.25
# 62  WH Ponsford        29    48         4  2122                266  48.22
# 63    SJ McCabe        39    62         5  2748                232  48.21
# 64   DR Jardine        22    33         6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  Rookie_Year  \
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs   Runs Highest_Inns_Score  \
# 0         DG Bradman        52    80        10   6996                334
# 1        YBK Jaiswal        11    20         1   1217                214
# 2           AC Voges        20    31         7   1485                269
# 3         RG Pollock        23    41         4   2256                274
# 4         GA Headley        22    40         4   2190                270
# 5        H Sutcliffe        54    84         9   4555                194
# 6          E Paynter        20    31         5   1540                243
# 7      KF Barrington        82   131        15   6806                256
# 8          ED Weekes        48    81         5   4455                207
# 9         WR Hammond        85   140        16   7249                336
# 10         GS Sobers        93   160        21   8032                365
# 11     KC Sangakkara       134   233        17  12400                319
# ...

# %%
#Dropping the rows with  no values

# %%
df = df.drop({8, 10, 15, 56}, axis = 0)

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int32
# 6s                       int32
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int32
# 6s                       int32
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
## QUETION Build out Career_Length Column

# %%
df['Career_Length'] = df['Final_Year'] - df['Rookie_Year']

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0         DG Bradman        52    80        10   6996                 334
# 1        YBK Jaiswal        11    20         1   1217                 214
# 2           AC Voges        20    31         7   1485                 269
# 3         RG Pollock        23    41         4   2256                 274
# 4         GA Headley        22    40         4   2190                 270
# 5        H Sutcliffe        54    84         9   4555                 194
# 6          E Paynter        20    31         5   1540                 243
# 7      KF Barrington        82   131        15   6806                 256
# 9         WR Hammond        85   140        16   7249                 336
# 11     KC Sangakkara       134   233        17  12400                 319
# 12         SPD Smith       109   195        25   9685                 239
# 13          JB Hobbs        61   102         7   5410                 211
# ...

# %%
## Calculations with the dataframe

# %%
# 1. What is the average career length

# %%
df['Career_Length'].mean()
# Out:
# 12.932203389830509

# %%
# 2. what is the average Batting_Strike_Rate for cricketers who played over 10 years

# %%
df[df['Career_Length'] > 10]['Batting_Strike_Rate']
# Out:
# 0     58.60
# 4     56.00
# 5     34.59
# 7     42.42
# 9     38.07
# 11    54.19
# 12    53.50
# 13    46.22
# 16    39.34
# 18    45.97
# 20    51.43
# 23    51.53
# 24    63.88
# 25    54.04
# 27    60.51
# 28    45.99
# 29    42.51
# 30    52.39
# 31    52.12
# 32    58.72
# 36    43.31
# 37    43.35
# 38    48.64
# 39    60.10
# 40    54.51
# 41    56.92
# 42    41.09
# 43    69.77
# 44    38.81
# 45    51.45
# 46    54.02
# 48    40.16
# 49    30.04
# 50    82.23
# 52    55.92
# 54    55.78
# 55    29.11
# 57    46.92
# 58    43.74
# 59    49.16
# 60    59.67
# Name: Batting_Strike_Rate, dtype: float64

# %%
# 3. Find the number of cricketers who played before 1960

# %%
df[df['Rookie_Year'] < 1960]['Player'].count()
# Out:
# 19

# %%
# 4. Max Highest Inns Score by country

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('Highestinncountry').reset_index().sort_values('Highestinncountry', ascending = False)
# Out:
#     Country  Highestinncountry
# 5    ICC/WI                400
# 0       AUS                380
# 10       SL                374
# 1       ENG                364
# 3   ICC/PAK                329
# 2   ICC/IND                319
# 8       PAK                313
# 11       WI                291
# 9        SA                278
# 4    ICC/SA                277
# 6       IND                254
# 7        NZ                251
# 12      ZIM                232

# %%
# 5. Hundreds, Fifties, ducks (0) AVG by Country

# %%
df.groupby('Country')[['100', '50', '0']].mean()
# Out:
#                100      50          0
# Country
# AUS      20.625000  28.375   8.562500
# ENG      13.333333  22.500   4.416667
# ICC/IND  29.500000  47.500  12.000000
# ICC/PAK  25.000000  46.000  15.000000
# ICC/SA   36.000000  48.000  13.500000
# ICC/WI   34.000000  48.000  17.000000
# IND      24.200000  30.600   8.800000
# NZ       32.000000  35.000  11.000000
# PAK      17.600000  23.600   7.800000
# SA        9.800000  20.200   3.400000
# SL       28.666667  44.000  12.333333
# WI       15.400000  28.400   7.800000
# ZIM      12.000000  27.000   5.000000
